# %%
import datetime

# %%
mytime = datetime.time(13,20,1,20)

# %%
mytime.minute
# Out:
# 20

# %%
mytime.hour
# Out:
# 13

# %%
print(mytime)
# Out:
# 13:20:01.000020

# %%
mytime.microsecond
# Out:
# 20

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2026-03-27

# %%
today.year
# Out:
# 2026

# %%
today.month
# Out:
# 3

# %%
today.day
# Out:
# 27

# %%
today.ctime()
# Out:
# 'Fri Mar 27 00:00:00 2026'

# %%
from datetime import datetime

# %%
mydatetime = datetime(2026, 3, 27, 14, 20, 1)

# %%
print(mydatetime)
# Out:
# 2026-03-27 14:20:01

# %%
mydatetime.replace(year=2025)
# Out:
# datetime.datetime(2025, 3, 27, 14, 20, 1)

# %%
print(mydatetime)
# Out:
# 2026-03-27 14:20:01

# %%
from datetime import date

# %%
date1 = date(2026, 3, 27)
date2 = date(2026, 4, 18)

# %%
result = date1 - date2

# %%
type(result)
# Out:
# datetime.timedelta

# %%
result.days
# Out:
# -22

# %%
datetime1 = datetime(2021, 11, 3, 22, 0)

# %%
datetime2 = datetime(2021, 11, 3, 12, 0)

# %%
datetime1 - datetime2
# Out:
# datetime.timedelta(seconds=36000)

# %%
36000/60/60
# Out:
# 10.0

# %%
mydiff = datetime1 - datetime2

# %%
mydiff.seconds
# Out:
# 36000

# %%
mydiff.total_seconds()
# Out:
# 36000.0
