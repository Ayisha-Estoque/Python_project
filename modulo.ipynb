# %% [markdown]
# MODULO

# %%
def even_check(number):
    result = number % 2 == 0
    return result

# %%
even_check(20)
# Out:
# True

# %%
DYNAMIC MODULO

# %%
def even_check(number):
    result = number % 2 == 0
    return result

number = int(input('Enter your number: '))

result = even_check(number)

print(f'{number} is {result}')
# Out:
# 9 is False

# %%
def check_even_list(num_list):

    for number in num_list:
        if number % 2 == 0:
            return True
        else:
            pass #placeholder that means dont do anything

    return False

# %%
check_even_list([2,4,5])
# Out:
# True

# %%
check_even_list([1,3,2])
# Out:
# True

# %%
def check_even_list(num_list):
    
    even_numbers = []

    for number in num_list:

        if number % 2 == 0:
            even_numbers.append(number)
        else:
            pass #placeholder that means dont do anything

    return even_numbers

# %%
check_even_list([1,3,2])
# Out:
# [2]
