# %%
x = 25
def printer():
    x=50
    return x

# %%
print(x)
# Out:
# 25

# %%
print(printer())
# Out:
# 50

# %%
# lambda num:num**2

# %%
name = 'THIS IS A GLOBAL STRING'

def greet():
    # name = 'Sammy'

    def hello():
        # name = 'asdsfs'
        print("Hello " + name)
    
    hello()

greet()
# Out:
# Hello THIS IS A GLOBAL STRING

# %%
greet()
# Out:
# Hello THIS IS A GLOBAL STRING

# %%
x = 50

def func(x):
    print (f'X is {x}')
    x = 'mbnkghkjg'
    print(f'hgkuyglouiytou {x}')
    return x

# %%
func(x)
# Out:
# X is 50
# hgkuyglouiytou mbnkghkjg
# 'mbnkghkjg'

# %%
print(x)
# Out:
# 50

# %%
x = func(x)
# Out:
# X is 50
# hgkuyglouiytou mbnkghkjg
