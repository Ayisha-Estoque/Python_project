# %% [markdown]
# LIST

# %%
my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list = ['Hello' , 2, 3]

# %%
my_list
# Out:
# ['Hello', 2, 3]

# %%
len(my_list)
# Out:
# 3

# %%
mylist = ['one', 'two', 'three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
another_list = ['four', 'five']

# %%
mylist + another_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list = mylist + another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0].upper()
# Out:
# 'ONE'

# %% [markdown]
# append is a method to add new in the list

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.append('seven')

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven']

# %% [markdown]
# pop method is to remove something in the list

# %%
new_list.pop()
# Out:
# 'seven'

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'six'

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list.pop(0)
# Out:
# 'one'

# %%
new_list
# Out:
# ['two', 'three', 'four', 'five']

# %%
new_list = ['a', 'e', 'x', 'b', 'c']
num_list = [1, 2, 3, 4, 5]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list
# Out:
# [1, 2, 3, 4, 5]

# %%
new_list.sort()
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 2, 3, 4, 5]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [5, 4, 3, 2, 1]

# %%
my_sorted_list.reverse()

# %%
my_sorted_list
# Out:
# ['x', 'e', 'c', 'b', 'a']

# %%
num_list.pop(2)
# Out:
# 3

# %% [markdown]
# INSERT

# %%
num_list
# Out:
# [5, 4, 2, 1]

# %%
add = 3

# %%
middle = len(num_list) // 2

# %%
num_list.insert(middle, add)

# %%
num_list
# Out:
# [5, 4, 3, 2, 1]
