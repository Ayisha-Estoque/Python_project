# %% [markdown]
# DEF KEYWORD
#
# use snake case in naming

# %%
def opening(ayi):
    print('Hello' + (ayi))

# %%
def add_function(num1, num2):
    return 1 + 2

# %%
result = add_function(1,2)

# %%
print(result)
# Out:
# 3
