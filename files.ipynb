# %% [markdown]
# FILE
# types
# path
# file should be on the same path

# %%
# %%writefile myfile.txt
# Mama mo
# nb,kdbaslf
# alshfasj
# ahsfvaskfg
# Out:
# Writing myfile.txt

# %% [markdown]
# CALLING FILE

# %%
myfile = open('myfile.txt')

# %% [markdown]
# TO SEE THE DIRECTORY

# %%
pwd
# Out:
# 'c:\\Users\\ayish\\Downloads\\Python_project'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Mama mo\nnb,kdbaslf\nalshfasj\nahsfvaskfg\n'

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# TO RESET AND READ AGAIN

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Mama mo\nnb,kdbaslf\nalshfasj\nahsfvaskfg\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Mama mo\nnb,kdbaslf\nalshfasj\nahsfvaskfg\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Mama mo\n', 'nb,kdbaslf\n', 'alshfasj\n', 'ahsfvaskfg\n']

# %% [markdown]
# FOR PATH DIRECTORY
# myfile open("C:\\Users\\UserName\\Folder\\test.txt")

# %%
pwd
# Out:
# 'c:\\Users\\ayish\\Downloads\\Python_project'

# %% [markdown]
# TO CLOSE THE FILE

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Mama mo\nnb,kdbaslf\nalshfasj\nahsfvaskfg\n'

# %%
with open('myfile.txt',mode = 'r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'Mama mo\nnb,kdbaslf\nalshfasj\nahsfvaskfg\n'

# %% [markdown]
# r = read
# w = write / overwrite / create new
# a = append
# r+ = reading and writing
# w+ = writing and reading

# %%
with open('myfile.txt',mode = 'r') as myfile:
    contents = myfile.read()

# %%
# %%writefile my_new_file.txt
# ONE
# TWO
# THREE
# Out:
# Writing my_new_file.txt

# %%
with open('my_new_file.txt', mode = 'r') as f:
    print(f.read())
# Out:
# ONE
# TWO
# THREE

# %%
with open('my_new_file.txt', mode = 'a') as f:
    f.write('FOUR')

# %%
with open('my_new_file.txt', mode = 'r') as f:
    print(f.read())
# Out:
# ONE
# TWO
# THREE
# FOUR

# %%
with open('sdfsdsdgsdg.txt', mode= 'w') as f:
    f.write('NEW FILE!')

# %%
with open('sdfsdsdgsdg.txt', mode = 'r') as f:
    print(f.read())
# Out:
# NEW FILE!
