# %%
2+1
# Out:
# 3

# %%
4-3
# Out:
# 1

# %%
5*8
# Out:
# 40

# %%
10/2
# Out:
# 5.0

# %%
Modulo

# %%
7 % 4
# Out:
# 3

# %%
Power

# %%
2 ** 3
# Out:
# 8

# %%
Multiple operation

# %%
2 + 20 * 20 + 3
# Out:
# 405

# %%
(2 + 10) * (10 + 3)
# Out:
# 156

# %%
0.1 + 0.2 - 0.3
# Out:
# 5.551115123125783e-17

# %%
1/2
# Out:
# 0.5
