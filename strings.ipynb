# %%
" I'm going to run "
# Out:
# " I'm going to run "

# %%
print("I'm going to run")
# Out:
# I'm going to run

# %%
print('hello \nworld')
# Out:
# hello
# world

# %%
print ('hello\tworld')
# Out:
# hello	world

# %% [markdown]
# len for the count of alphabet that was used

# %%
len('hello')
# Out:
# 5

# %%
len("I'm hungry")
# Out:
# 10

# %% [markdown]
# indexing

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring[-3]
# Out:
# 'r'

# %%
mystring[-1]
# Out:
# 'd'

# %% [markdown]
# SLICING

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[6:]
# Out:
# 'World'

# %%
mystring[:5]
# Out:
# 'Hello'

# %%
mystring [5:]
# Out:
# ' World'

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[4:7]
# Out:
# 'o W'

# %%
mystring
# Out:
# 'Hello World'

# %% [markdown]
# STEP SIZE

# %%
mystring[1:8:3]
# Out:
# 'eoo'

# %% [markdown]
# REVERSE A STRING

# %%
mystring[::-1]
# Out:
# 'dlroW olleH'

# %% [markdown]
# IMMUTABILITY

# %%
name = "Sam"

# %%
last_letters = name[1:]

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = 'Hello World'

# %%
x = x + " it is beautiful outside!"

# %%
x
# Out:
# 'Hello World it is beautiful outside!'

# %%
x * 10
# Out:
# 'Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!Hello World it is beautiful outside!'

# %%
x = 'Hello World'

# %% [markdown]
# UPPERCASE

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x
# Out:
# 'Hello World'

# %% [markdown]
# LOWERCASE

# %%
x.lower()
# Out:
# 'hello world'

# %% [markdown]
# SPLIT

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
x.split('o')
# Out:
# ['Hell', ' W', 'rld']

# %% [markdown]
# PRINT FORMATTING
# .format method (concatination)

# %%
print ('This is a string {}'.format('INSERTED'))
# Out:
# This is a string INSERTED

# %%
print ('The {2} {1} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print ('The {q} {b} {f}'.format(f = 'fox', b = 'brown', q = 'quick'))
# Out:
# The quick brown fox

# %% [markdown]
# float formatting method

# %%
result = 100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print ("The result was {}".format(result))
# Out:
# The result was 0.1287001287001287

# %%
print ("The result was {r}".format(r = result))
# Out:
# The result was 0.1287001287001287

# %% [markdown]
# ROUNDOFF

# %%
print ("The result was {r:1.3f}".format(r = result))
# Out:
# The result was 0.129

# %% [markdown]
# .format REPLACEMENT

# %%
name = 'Ayi'

# %%
print (f'Hello, my namen is {name}')
# Out:
# Hello, my namen is Ayi

# %%
age = 21

# %%
print (f'{name} is {age} years old')
# Out:
# Ayi is 21 years old

# %%
print('Python {}'.format ('rules!'))
# Out:
# Python rules!
