# %%
hex(12)
# Out:
# '0xc'

# %%
bin(512)
# Out:
# '0b1000000000'

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
pow(2,4,3)
# Out:
# 1

# %%
abs(-3)
# Out:
# 3

# %%
abs(2)
# Out:
# 2

# %%
round(3.9)
# Out:
# 4

# %%
round(3.141592,2)
# Out:
# 3.14

# %% [markdown]
# ### ADVANCED STRINGS

# %%
s = 'hellp world'

# %%
s.capitalize()
# Out:
# 'Hellp world'

# %%
s.upper()
# Out:
# 'HELLP WORLD'

# %%
s.lower()
# Out:
# 'hellp world'

# %%
s.count('o')
# Out:
# 1

# %%
s.find('o')
# Out:
# 7

# %%
s
# Out:
# 'hellp world'

# %%
s.center(20,'z')
# Out:
# 'zzzzhellp worldzzzzz'

# %%
'hello\thi'
# Out:
# 'hello\thi'

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
s = 'hello'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s
# Out:
# 'hello'

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %%
s.endswith('o')
# Out:
# True

# %%
s[-1] == 'o'
# Out:
# True

# %%
s
# Out:
# 'hello'

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s = 'hihihihih'

# %%
s.split('i')
# Out:
# ['h', 'h', 'h', 'h', 'h']

# %%
s.partition('i')
# Out:
# ('h', 'i', 'hihihih')

# %% [markdown]
# ### ADVANCED SETS

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s={1,2,3}

# %%
sc = s.copy()

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
sc
# Out:
# {1, 2, 3}

# %%
s.difference(sc)
# Out:
# {4}

# %%
s1 = {1,2,3}
s2 = {4,5,6}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {1, 2, 3}

# %%
s2
# Out:
# {4, 5, 6}

# %%
s1 = {1,2,3}
s2 = {1,2,4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1 = {1,2}
s2 = {1,2,4}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s3
# Out:
# {5}

# %%
s1.issubset(s2)
# Out:
# True

# %%
s2.issuperset(s1)
# Out:
# True

# %%
s1.symmetric_difference(s2)
# Out:
# {4}

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 4}

# %% [markdown]
# ### ADVANCED DICTIOANRY

# %%
d = {'k1':1, 'k2':2}

# %%
{k:v**2 for k,v in zip(['a','b'],range(2))}
# Out:
# {'a': 0, 'b': 1}

# %%
for k in d.values():
    print(k)
# Out:
# 1
# 2

# %%
d.values()
# Out:
# dict_values([1, 2])

# %% [markdown]
# ### ADVANCED LISTS

# %%
l = [1,2,3]

# %%
l.append(4)

# %%
l.count(10)
# Out:
# 0

# %%
l.count(1)
# Out:
# 1

# %%
x = [1,2,3]
x.append([4,5])
print (x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
x = [1,2,3]
x.extend([4,5])
print (x)
# Out:
# [1, 2, 3, 4, 5]

# %%
l.index(2)
# Out:
# 1

# %%
l.insert(2,'inserted')

# %%
l
# Out:
# [1, 2, 'inserted', 3, 4]

# %%
ele = l.pop()

# %%
ele
# Out:
# 4

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 'inserted', 3]

# %%
l.remove('inserted')

# %%
l
# Out:
# [2, 3]

# %%
l = [1,2,3,4,3]

# %%
l.remove(3)

# %%
l
# Out:
# [1, 2, 4, 3]

# %%
l.reverse()
