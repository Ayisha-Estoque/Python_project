# %% [markdown]
# BOOLEANS
# convey TRUE OR FLASE
# always capitalized the first letter

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
1>2
# Out:
# False

# %%
1==1
# Out:
# True
