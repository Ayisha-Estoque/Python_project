# %% [markdown]
# COMPARISON OPERATOR

# %%
2 ==2
# Out:
# True

# %%
2==1
# Out:
# False

# %%
'hello' == 'bye'
# Out:
# False

# %% [markdown]
# KEY SENSITIVE

# %%
3 != 3
# Out:
# False

# %%
5 !=3
# Out:
# True

# %%
3>2
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
4 <= 2
# Out:
# False

# %% [markdown]
# CHAINING COMPARISON OPERATOR
# LOGICAL OPERATOR

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %% [markdown]
# AND

# %%
1 < 3 and 2 < 3
# Out:
# True

# %%
('h' == 'h') and (2 == 2)
# Out:
# True

# %%
(1 == 1) or (2 == 2)
# Out:
# True

# %%
not (1 == 1)
#opposite
# Out:
# False
