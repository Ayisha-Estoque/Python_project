# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
b = 2

# %%
a
# Out:
# 10

# %%
a + b
# Out:
# 12

# %%
(a + a) * b
# Out:
# 40

# %%
a = a**a

# %%
a
# Out:
# 10000000000

# %%
type (a)
# Out:
# int

# %%
a = 30.1

# %%
type (a)
# Out:
# float

# %%
my_income = 1000

tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 100.0
