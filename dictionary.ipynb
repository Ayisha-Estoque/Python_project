# %% [markdown]
# DICTIONARY
# name:value

# %%
my_dict = {'A': 'Mama mo', 'B': 'Weh'}

# %%
my_dict['A']
# Out:
# 'Mama mo'

# %%
d = {'A': 123, 'B': [0,1,2], 'C':{'insideKey':100}}

# %%
d['B']
# Out:
# [0, 1, 2]

# %%
d['C']['insideKey']
# Out:
# 100

# %%
d = {'A':['d', 'e', 'f']}

# %%
d
# Out:
# {'A': ['d', 'e', 'f']}

# %%
my_list = d['A']

# %%
my_list
# Out:
# ['d', 'e', 'f']

# %%
letter = my_list[1]

# %%
letter
# Out:
# 'e'

# %%
letter.upper()
# Out:
# 'E'

# %%
my_list
# Out:
# ['d', 'e', 'f']

# %%
d
# Out:
# {'A': ['d', 'e', 'f']}

# %%
d['B'] = ['g', 'h', 'i']

# %%
d
# Out:
# {'A': ['d', 'e', 'f'], 'B': ['g', 'h', 'i']}

# %% [markdown]
# VIEW PER BATCH

# %%
d.keys()
# Out:
# dict_keys(['A', 'B'])

# %%
d.values()
# Out:
# dict_values([['d', 'e', 'f'], ['g', 'h', 'i']])

# %%
d.items()
# Out:
# dict_items([('A', ['d', 'e', 'f']), ('B', ['g', 'h', 'i'])])
